# %%
#name entity recognition
# words -- automatic predefined categories
##person , 
##location
##organization
##date
##time
##money
##percentage
##fraction

# %%
paragraph = """
The Eiffel Tower, located in Paris, France, is one of the most iconic landmarks in the world. Designed by engineer Gustave Eiffel, it was constructed between 1887 and 1889 as the entrance arch to the 1889 World's Fair, held to celebrate the 100th anniversary of the French Revolution. Made of wrought iron and standing at a height of approximately 330 meters, the tower was initially met with criticism from artists and intellectuals who found its design unappealing. However, it soon became a beloved symbol of Paris and a marvel of modern engineering. The Eiffel Tower has three public levels, offering breathtaking views of the city, restaurants, and even a glass floor on the first level. It attracts millions of visitors each year and is regularly maintained by being repainted every seven years. Today, the Eiffel Tower stands not just as a feat of architectural brilliance, but also as a timeless emblem of France’s cultural and historical legacy."""

# %%
import nltk

# %%
# sen = nltk.sent_tokenize(paragraph)
words = nltk.word_tokenize(paragraph)
tag_elements = nltk.pos_tag(words)

# %%
nltk.ne_chunk(tag_elements)
# Out:
# Tree('S', [('The', 'DT'), Tree('ORGANIZATION', [('Eiffel', 'NNP'), ('Tower', 'NNP')]), (',', ','), ('located', 'VBN'), ('in', 'IN'), Tree('GPE', [('Paris', 'NNP')]), (',', ','), Tree('GPE', [('France', 'NNP')]), (',', ','), ('is', 'VBZ'), ('one', 'CD'), ('of', 'IN'), ('the', 'DT'), ('most', 'RBS'), ('iconic', 'JJ'), ('landmarks', 'NNS'), ('in', 'IN'), ('the', 'DT'), ('world', 'NN'), ('.', '.'), ('Designed', 'VBN'), ('by', 'IN'), ('engineer', 'NN'), Tree('PERSON', [('Gustave', 'NNP'), ('Eiffel', 'NNP')]), (',', ','), ('it', 'PRP'), ('was', 'VBD'), ('constructed', 'VBN'), ('between', 'IN'), ('1887', 'CD'), ('and', 'CC'), ('1889', 'CD'), ('as', 'IN'), ('the', 'DT'), ('entrance', 'NN'), ('arch', 'NN'), ('to', 'TO'), ('the', 'DT'), ('1889', 'CD'), ('World', 'NNP'), ("'s", 'POS'), Tree('PERSON', [('Fair', 'NNP')]), (',', ','), ('held', 'VBD'), ('to', 'TO'), ('celebrate', 'VB'), ('the', 'DT'), ('100th', 'JJ'), ('anniversary', 'NN'), ('of', 'IN'), ('the', 'DT'), Tree('GPE', [('French', 'JJ')]), ('Revolution', 'NNP'), ('.', '.'), Tree('PERSON', [('Made', 'NNP')]), ('of', 'IN'), ('wrought', 'JJ'), ('iron', 'NN'), ('and', 'CC'), ('standing', 'NN'), ('at', 'IN'), ('a', 'DT'), ('height', 'NN'), ('of', 'IN'), ('approximately', 'RB'), ('330', 'CD'), ('meters', 'NNS'), (',', ','), ('the', 'DT'), ('tower', 'NN'), ('was', 'VBD'), ('initially', 'RB'), ('met', 'VBN'), ('with', 'IN'), ('criticism', 'NN'), ('from', 'IN'), ('artists', 'NNS'), ('and', 'CC'), ('intellectuals', 'NNS'), ('who', 'WP'), ('found', 'VBD'), ('its', 'PRP$'), ('design', 'NN'), ('unappealing', 'NN'), ('.', '.'), ('However', 'RB'), (',', ','), ('it', 'PRP'), ('soon', 'RB'), ('became', 'VBD'), ('a', 'DT'), ('beloved', 'JJ'), ('symbol', 'NN'), ('of', 'IN'), Tree('GPE', [('Paris', 'NNP')]), ('and', 'CC'), ('a', 'DT'), ('marvel', 'NN'), ('of', 'IN'), ('modern', 'JJ'), ('engineering', 'NN'), ('.', '.'), ('The', 'DT'), Tree('ORGANIZATION', [('Eiffel', 'NNP'), ('Tower', 'NNP')]), ('has', 'VBZ'), ('three', 'CD'), ('public', 'JJ'), ('levels', 'NNS'), (',', ','), ('offering', 'VBG'), ('breathtaking', 'VBG'), ('views', 'NNS'), ('of', 'IN'), ('the', 'DT'), ('city', 'NN'), (',', ','), ('restaurants', 'NNS'), (',', ','), ('and', 'CC'), ('even', 'RB'), ('a', 'DT'), ('glass', 'NN'), ('floor', 'NN'), ('on', 'IN'), ('the', 'DT'), ('first', 'JJ'), ('level', 'NN'), ('.', '.'), ('It', 'PRP'), ('attracts', 'VBZ'), ('millions', 'NNS'), ('of', 'IN'), ('visitors', 'NNS'), ('each', 'DT'), ('year', 'NN'), ('and', 'CC'), ('is', 'VBZ'), ('regularly', 'RB'), ('maintained', 'VBN'), ('by', 'IN'), ('being', 'VBG'), ('repainted', 'VBN'), ('every', 'DT'), ('seven', 'CD'), ('years', 'NNS'), ('.', '.'), ('Today', 'NN'), (',', ','), ('the', 'DT'), Tree('ORGANIZATION', [('Eiffel', 'NNP'), ('Tower', 'NNP')]), ('stands', 'VBZ'), ('not', 'RB'), ('just', 'RB'), ('as', 'IN'), ('a', 'DT'), ('feat', 'NN'), ('of', 'IN'), ('architectural', 'JJ'), ('brilliance', 'NN'), (',', ','), ('but', 'CC'), ('also', 'RB'), ('as', 'IN'), ('a', 'DT'), ('timeless', 'NN'), ('emblem', 'NN'), ('of', 'IN'), Tree('GPE', [('France', 'NNP')]), ('’', 'NNP'), ('s', 'JJ'), ('cultural', 'JJ'), ('and', 'CC'), ('historical', 'JJ'), ('legacy', 'NN'), ('.', '.')])
