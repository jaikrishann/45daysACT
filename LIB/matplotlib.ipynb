# %%
#matplot and seaborn -- data visualization-- graphs andd plots
# lineplot , barplot , histogram , piechart , scatterplot

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
arr = np.random.randint(20000,40000,100)
arr
# Out:
# array([23786, 32771, 35656, 22353, 21058, 28615, 21858, 38134, 30249,
#        23944, 21512, 35036, 39794, 38459, 22058, 28454, 27585, 28561,
#        25461, 39169, 25774, 25012, 26091, 38007, 33378, 25583, 26299,
#        23146, 29872, 33715, 22326, 26723, 20478, 38643, 31900, 32555,
#        31131, 37292, 26208, 28489, 26755, 38913, 39611, 29164, 20261,
#        20449, 31418, 35042, 32595, 38272, 21498, 21343, 20168, 36027,
#        27167, 21084, 25343, 20917, 26150, 25994, 21077, 36765, 22985,
#        24791, 36785, 35992, 31402, 24387, 24983, 27706, 39040, 30549,
#        26420, 39187, 33023, 28480, 36016, 21233, 24067, 32583, 34297,
#        28823, 38489, 31037, 34323, 29251, 27717, 39372, 29664, 31375,
#        30597, 29113, 25690, 21146, 26700, 20165, 37345, 24077, 24121,
#        31439])

# %%
##linepllot  -- numerical data 
arr.sort()
plt.plot(arr)
plt.show()

# %%
x = [1,2,3,4,5]
y = [1,10,9,30,25]
plt.plot(x,y,marker = "s",ms = 10,
         mfc = "red",mec = "green",
         color = "black",
         lw = 3,ls = ":",
         alpha = 0.7,label = "lineplot")
plt.title("lineplot")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.legend()
plt.show()

# %%
#scattrplot  
plt.scatter(x,y,marker="D")
plt.show()

# %%
df = pd.read_csv("Used_Bikes.csv")
df.head()
# Out:
#                               bike_name     price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1           Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
#
#          owner  age  power          brand
# 0  First Owner  3.0  110.0            TVS
# 1  First Owner  4.0  350.0  Royal Enfield
# 2  First Owner  8.0  675.0        Triumph
# 3  First Owner  4.0  180.0            TVS
# 4  First Owner  3.0  150.0         Yamaha

# %%
# plt.scatter(df["kms_driven"],df["price"])
# plt.plot(df["kms_driven"],df["price"])

# %%
x = ["mp","up","rj","gj"]
y = [10,20,30,40]
colours = ["red","green","blue","yellow"]
hatch_patterns = ["//","\\\\","xx","oo"]
# plt.bar(x,y,color = colours,hatch = hatch_patterns,
#         label = x,width=0.3,edgecolor = "black",alpha = 0.7,
#         linewidth = 3)
plt.barh(x,y)
plt.legend()
# plt.grid()
plt.show()
# Out:
# C:\Users\jaikr\AppData\Local\Temp\ipykernel_15120\348918899.py:9: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
##histogram -- distribution of data in interval(bins)
arr = np.random.randint(20000,40000,100)
plt.hist(arr,bins=20)
plt.show()

# %%
##piechart -- percentage
x = ["mp","up","rj","gj"]
y = [10,20,30,40]
explodes  = (4,0,0,0)
plt.pie(y,labels = x,autopct="%1.2f%%",shadow=True,explode = explodes)
plt.savefig("piechart.pdf")
plt.show()
#savefig

# %%
##subplot 
import warnings
warnings.filterwarnings("ignore")


x = np.linspace(0,10,100)
plt.figure(figsize=(10,6))
plt.subplot(2,2,1) ##2 rows , 2 columns , 1st graph
plt.plot(x,np.sin(x))
plt.title("sin")
plt.subplot(2,2,2) ##2 rows , 2 columns , 2nd graph
plt.plot(x,np.cos(x))
plt.title("cos")
plt.subplot(2,2,3) ##2 rows , 2 columns , 3rd graph
plt.plot(x,np.tan(x))
plt.title("tan")
plt.subplot(2,2,4) ##2 rows , 2 columns , 4th graph
plt.plot(x,np.log(x))
plt.title("log")
plt.tight_layout()
plt.show()
